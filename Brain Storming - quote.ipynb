# %% [markdown]
# # RDF N-Triples Analysis Notebook using rdflib

# %%
name = "quote"

# %% [markdown]
# # =========================
#
# # 1. Setup
#
# # =========================

# %%
from rdflib import Graph, URIRef, Literal, Namespace
from rdflib.namespace import RDF, RDFS, SKOS, XSD
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

# %% [markdown]
# ## Helper Functions

# %%
def parse_file_safe(graph, path):
    encodings = ["utf-8", "latin-1", "cp1252"]

    for enc in encodings:
        try:
            with open(path, "r", encoding=enc) as f:
                graph.parse(f, format="nt")
            print(f"Loaded {path} with {enc}")
            return
        except UnicodeDecodeError:
            continue

    print(f"Failed to parse {path}")

# %% [markdown]
# # =========================
#
# # 2. Load N-Triples Files
#
# # =========================

# %%
import os

data_dir = "data"
g = Graph()


for file in os.listdir(data_dir):
    if name in file and file.endswith(".ntriples"):
        path = os.path.join(data_dir, file)
        print(f"Loading {path}")
        parse_file_safe(g, path)

print(f"Total triples loaded: {len(g)}")
# Out:
# Loading data\OpenPermID-bulk-quote.ntriples
# Loaded data\OpenPermID-bulk-quote.ntriples with utf-8
# Total triples loaded: 360

# %% [markdown]
# # =========================
#
# # 3. Inspect Basic Structure
#
# # =========================

# %%
# Print first 10 triples
for i, (s, p, o) in enumerate(g):
    if i >= 10:
        break
    print(s, p, o)
# Out:
# https://permid.org/quote-0046 https://permid.org/ontology/financial/lotSize 1
# https://permid.org/quote-0059 http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://permid.org/ontology/financial/SecondaryQuote
# https://permid.org/quote-0016 http://www.w3.org/2000/01/rdf-schema#label Quote-0016
# https://permid.org/quote-0008 https://permid.org/ontology/financial/lotSize 1000
# https://permid.org/quote-0026 https://permid.org/ontology/financial/quotedOrganization https://permid.org/org-0026
# https://permid.org/quote-0026 https://permid.org/ontology/financial/listedOn SSE
# https://permid.org/quote-0036 https://permid.org/ontology/financial/quotedOrganization https://permid.org/org-0006
# https://permid.org/quote-0021 https://permid.org/ontology/financial/lotSize 1
# https://permid.org/quote-0014 https://permid.org/ontology/financial/lotSize 10
# https://permid.org/quote-0054 https://permid.org/ontology/financial/lotSize 100

# %% [markdown]
# # =========================
#
# # 4. Explore Unique Elements
#
# # =========================

# %%
subjects = set()
predicates = set()
uri_predicates = set()
literal_predicates = set()
objects = set()
both = set()
count = 0
for s, p, o in g:
    subjects.add(s)
    predicates.add(p)
    objects.add(o)
    both.add(s)
    both.add(o)
    if isinstance(o, Literal):
        literal_predicates.add(p)
    else:
        uri_predicates.add(p)
    count += 1


print("Total Size:", count)
print("Unique subjects:", len(subjects))
print("Unique predicates:", len(predicates))
print("Unique objects:", len(objects))
print("Unique Both:", len(both))
# Out:
# Total Size: 360
# Unique subjects: 60
# Unique predicates: 6
# Unique objects: 127
# Unique Both: 187

# %%
print(uri_predicates)
# Out:
# {rdflib.term.URIRef('https://permid.org/ontology/financial/quoteCurrency'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('https://permid.org/ontology/financial/quotedOrganization')}

# %%
print(literal_predicates)
# Out:
# {rdflib.term.URIRef('https://permid.org/ontology/financial/listedOn'), rdflib.term.URIRef('https://permid.org/ontology/financial/lotSize'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label')}

# %% [markdown]
# Conclusion: Majority of subjects are not objects

# %% [markdown]
# # =========================
#
# # 5. Convert to DataFrame
#
# # =========================

# %%
data = [(str(s), str(p), str(o)) for s, p, o in g]
df = pd.DataFrame(data, columns=["subject", "predicate", "object"])

df.head()

# Predicate frequency
predicate_counts = df["predicate"].value_counts()
predicate_counts.head(10)
# Out:
# predicate
# https://permid.org/ontology/financial/lotSize               60
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type             60
# http://www.w3.org/2000/01/rdf-schema#label                  60
# https://permid.org/ontology/financial/quotedOrganization    60
# https://permid.org/ontology/financial/listedOn              60
# https://permid.org/ontology/financial/quoteCurrency         60
# Name: count, dtype: int64

# %% [markdown]
# # =========================
#
# # 6. Namespace Handling
#
# # =========================

# %%
EX = Namespace("http://permid.org/")

# Bind namespace (useful for serialization)
g.bind("ex", EX)

# %% [markdown]
# # =========================
#
# # 7. Filtering Triples
#
# # =========================

# %%
# Example: get all labels
labels = []
for s, p, o in g.triples((None, RDFS.label, None)):
    labels.append((s, o))

print("Sample labels:")
print(labels[:10])
# Out:
# Sample labels:
# [(rdflib.term.URIRef('https://permid.org/quote-0001'), rdflib.term.Literal('Quote-0001', lang='en')), (rdflib.term.URIRef('https://permid.org/quote-0002'), rdflib.term.Literal('Quote-0002', lang='en')), (rdflib.term.URIRef('https://permid.org/quote-0003'), rdflib.term.Literal('Quote-0003', lang='en')), (rdflib.term.URIRef('https://permid.org/quote-0004'), rdflib.term.Literal('Quote-0004', lang='en')), (rdflib.term.URIRef('https://permid.org/quote-0005'), rdflib.term.Literal('Quote-0005', lang='en')), (rdflib.term.URIRef('https://permid.org/quote-0006'), rdflib.term.Literal('Quote-0006', lang='en')), (rdflib.term.URIRef('https://permid.org/quote-0007'), rdflib.term.Literal('Quote-0007', lang='en')), (rdflib.term.URIRef('https://permid.org/quote-0008'), rdflib.term.Literal('Quote-0008', lang='en')), (rdflib.term.URIRef('https://permid.org/quote-0009'), rdflib.term.Literal('Quote-0009', lang='en')), (rdflib.term.URIRef('https://permid.org/quote-0010'), rdflib.term.Literal('Quote-0010', lang='en'))]

# %% [markdown]
# # =========================
#
# # 8. SPARQL Queries
#
# # =========================

# %%
query = """
SELECT ?s ?label
WHERE {
    # ?s <http://www.w3.org/2000/01/rdf-schema#label> ?label .
}
LIMIT 10
"""

for row in g.query(query):
    print(row)

# More complex query: hierarchical relations
query_hierarchy = """
SELECT ?child ?parent
WHERE {
    # ?child <http://www.w3.org/2004/02/skos/core#broader> ?parent .
}
LIMIT 10
"""

for row in g.query(query_hierarchy):
    print(row)
# Out:
# (rdflib.term.URIRef('https://permid.org/quote-0001'), rdflib.term.Literal('Quote-0001', lang='en'))
# (rdflib.term.URIRef('https://permid.org/quote-0002'), rdflib.term.Literal('Quote-0002', lang='en'))
# (rdflib.term.URIRef('https://permid.org/quote-0003'), rdflib.term.Literal('Quote-0003', lang='en'))
# (rdflib.term.URIRef('https://permid.org/quote-0004'), rdflib.term.Literal('Quote-0004', lang='en'))
# (rdflib.term.URIRef('https://permid.org/quote-0005'), rdflib.term.Literal('Quote-0005', lang='en'))
# (rdflib.term.URIRef('https://permid.org/quote-0006'), rdflib.term.Literal('Quote-0006', lang='en'))
# (rdflib.term.URIRef('https://permid.org/quote-0007'), rdflib.term.Literal('Quote-0007', lang='en'))
# (rdflib.term.URIRef('https://permid.org/quote-0008'), rdflib.term.Literal('Quote-0008', lang='en'))
# (rdflib.term.URIRef('https://permid.org/quote-0009'), rdflib.term.Literal('Quote-0009', lang='en'))
# (rdflib.term.URIRef('https://permid.org/quote-0010'), rdflib.term.Literal('Quote-0010', lang='en'))

# %% [markdown]
# # =========================
#
# # 9. Working with Literals
#
# # =========================

# %%
for s, p, o in g:
    if isinstance(o, Literal):
        print("Value:", o)
        print("Datatype:", o.datatype)
        print("Python value:", o.toPython())
        print("_---------------------_")
# Out:
# Value: 1
# Datatype: None
# Python value: 1
# _---------------------_
# Value: Quote-0016
# Datatype: None
# Python value: Quote-0016
# _---------------------_
# Value: 1000
# Datatype: None
# Python value: 1000
# _---------------------_
# Value: SSE
# Datatype: None
# Python value: SSE
# _---------------------_
# Value: 1
# Datatype: None
# Python value: 1
# _---------------------_
# Value: 10
# Datatype: None
# Python value: 10
# _---------------------_
# Value: 100
# Datatype: None
# Python value: 100
# _---------------------_
# Value: TSE
# Datatype: None
# Python value: TSE
# _---------------------_
# Value: Quote-0012
# Datatype: None
# Python value: Quote-0012
# _---------------------_
# Value: Quote-0050
# Datatype: None
# Python value: Quote-0050
# _---------------------_
# Value: Quote-0006
# Datatype: None
# Python value: Quote-0006
# _---------------------_
# Value: 10
# Datatype: None
# Python value: 10
# _---------------------_
# Value: Quote-0042
# Datatype: None
# Python value: Quote-0042
# _---------------------_
# Value: Quote-0035
# Datatype: None
# Python value: Quote-0035
# _---------------------_
# Value: 10
# Datatype: None
# Python value: 10
# _---------------------_
# Value: 100
# Datatype: None
# Python value: 100
# _---------------------_
# Value: Euronext
# Datatype: None
# Python value: Euronext
# _---------------------_
# Value: LSE
# Datatype: None
# Python value: LSE
# _---------------------_
# Value: Quote-0060
# Datatype: None
# Python value: Quote-0060
# _---------------------_
# Value: ASX
# Datatype: None
# Python value: ASX
# _---------------------_
# Value: Quote-0029
# Datatype: None
# Python value: Quote-0029
# _---------------------_
# Value: Quote-0053
# Datatype: None
# Python value: Quote-0053
# _---------------------_
# Value: 1
# Datatype: None
# Python value: 1
# _---------------------_
# Value: Quote-0019
# Datatype: None
# Python value: Quote-0019
# _---------------------_
# Value: ASX
# Datatype: None
# Python value: ASX
# _---------------------_
# Value: 10
# Datatype: None
# Python value: 10
# _---------------------_
# Value: HKEX
# Datatype: None
# Python value: HKEX
# _---------------------_
# Value: Quote-0051
# Datatype: None
# Python value: Quote-0051
# _---------------------_
# Value: Quote-0022
# Datatype: None
# Python value: Quote-0022
# _---------------------_
# Value: Quote-0030
# Datatype: None
# Python value: Quote-0030
# _---------------------_
# Value: LSE
# Datatype: None
# Python value: LSE
# _---------------------_
# Value: SSE
# Datatype: None
# Python value: SSE
# _---------------------_
# Value: Euronext
# Datatype: None
# Python value: Euronext
# _---------------------_
# Value: TSE
# Datatype: None
# Python value: TSE
# _---------------------_
# Value: Quote-0047
# Datatype: None
# Python value: Quote-0047
# _---------------------_
# Value: Quote-0039
# Datatype: None
# Python value: Quote-0039
# _---------------------_
# Value: 1
# Datatype: None
# Python value: 1
# _---------------------_
# Value: 10
# Datatype: None
# Python value: 10
# _---------------------_
# Value: 1000
# Datatype: None
# Python value: 1000
# _---------------------_
# Value: Quote-0040
# Datatype: None
# Python value: Quote-0040
# _---------------------_
# Value: 1000
# Datatype: None
# Python value: 1000
# _---------------------_
# Value: TSE
# Datatype: None
# Python value: TSE
# _---------------------_
# Value: 100
# Datatype: None
# Python value: 100
# _---------------------_
# Value: Quote-0046
# Datatype: None
# Python value: Quote-0046
# _---------------------_
# Value: 1
# Datatype: None
# Python value: 1
# _---------------------_
# Value: Quote-0032
# Datatype: None
# Python value: Quote-0032
# _---------------------_
# Value: 100
# Datatype: None
# Python value: 100
# _---------------------_
# Value: Quote-0002
# Datatype: None
# Python value: Quote-0002
# _---------------------_
# Value: SSE
# Datatype: None
# Python value: SSE
# _---------------------_
# Value: 1000
# Datatype: None
# Python value: 1000
# _---------------------_
# Value: HKEX
# Datatype: None
# Python value: HKEX
# _---------------------_
# Value: NASDAQ
# Datatype: None
# Python value: NASDAQ
# _---------------------_
# Value: 100
# Datatype: None
# Python value: 100
# _---------------------_
# Value: 10
# Datatype: None
# Python value: 10
# _---------------------_
# Value: 100
# Datatype: None
# Python value: 100
# _---------------------_
# Value: Quote-0025
# Datatype: None
# Python value: Quote-0025
# _---------------------_
# Value: Quote-0013
# Datatype: None
# Python value: Quote-0013
# _---------------------_
# Value: 1
# Datatype: None
# Python value: 1
# _---------------------_
# Value: ASX
# Datatype: None
# Python value: ASX
# _---------------------_
# Value: NASDAQ
# Datatype: None
# Python value: NASDAQ
# _---------------------_
# Value: SSE
# Datatype: None
# Python value: SSE
# _---------------------_
# Value: Euronext
# Datatype: None
# Python value: Euronext
# _---------------------_
# Value: BSE
# Datatype: None
# Python value: BSE
# _---------------------_
# Value: NASDAQ
# Datatype: None
# Python value: NASDAQ
# _---------------------_
# Value: Quote-0023
# Datatype: None
# Python value: Quote-0023
# _---------------------_
# Value: TSE
# Datatype: None
# Python value: TSE
# _---------------------_
# Value: Quote-0021
# Datatype: None
# Python value: Quote-0021
# _---------------------_
# Value: 1000
# Datatype: None
# Python value: 1000
# _---------------------_
# Value: Quote-0041
# Datatype: None
# Python value: Quote-0041
# _---------------------_
# Value: 10
# Datatype: None
# Python value: 10
# _---------------------_
# Value: Quote-0054
# Datatype: None
# Python value: Quote-0054
# _---------------------_
# Value: NYSE
# Datatype: None
# Python value: NYSE
# _---------------------_
# Value: Euronext
# Datatype: None
# Python value: Euronext
# _---------------------_
# Value: 1000
# Datatype: None
# Python value: 1000
# _---------------------_
# Value: NYSE
# Datatype: None
# Python value: NYSE
# _---------------------_
# Value: LSE
# Datatype: None
# Python value: LSE
# _---------------------_
# Value: Quote-0059
# Datatype: None
# Python value: Quote-0059
# _---------------------_
# Value: 100
# Datatype: None
# Python value: 100
# _---------------------_
# Value: HKEX
# Datatype: None
# Python value: HKEX
# _---------------------_
# Value: SGX
# Datatype: None
# Python value: SGX
# _---------------------_
# Value: 1000
# Datatype: None
# Python value: 1000
# _---------------------_
# Value: BSE
# Datatype: None
# Python value: BSE
# _---------------------_
# Value: 1000
# Datatype: None
# Python value: 1000
# _---------------------_
# Value: Quote-0011
# Datatype: None
# Python value: Quote-0011
# _---------------------_
# Value: NYSE
# Datatype: None
# Python value: NYSE
# _---------------------_
# Value: Quote-0049
# Datatype: None
# Python value: Quote-0049
# _---------------------_
# Value: 1000
# Datatype: None
# Python value: 1000
# _---------------------_
# Value: 10
# Datatype: None
# Python value: 10
# _---------------------_
# Value: Quote-0024
# Datatype: None
# Python value: Quote-0024
# _---------------------_
# Value: Quote-0026
# Datatype: None
# Python value: Quote-0026
# _---------------------_
# Value: HKEX
# Datatype: None
# Python value: HKEX
# _---------------------_
# Value: 1
# Datatype: None
# Python value: 1
# _---------------------_
# Value: Quote-0034
# Datatype: None
# Python value: Quote-0034
# _---------------------_
# Value: 100
# Datatype: None
# Python value: 100
# _---------------------_
# Value: Quote-0057
# Datatype: None
# Python value: Quote-0057
# _---------------------_
# Value: NYSE
# Datatype: None
# Python value: NYSE
# _---------------------_
# Value: 1
# Datatype: None
# Python value: 1
# _---------------------_
# Value: 100
# Datatype: None
# Python value: 100
# _---------------------_
# Value: 100
# Datatype: None
# Python value: 100
# _---------------------_
# Value: Quote-0017
# Datatype: None
# Python value: Quote-0017
# _---------------------_
# Value: SGX
# Datatype: None
# Python value: SGX
# _---------------------_
# Value: Quote-0055
# Datatype: None
# Python value: Quote-0055
# _---------------------_
# Value: 10
# Datatype: None
# Python value: 10
# _---------------------_
# Value: NASDAQ
# Datatype: None
# Python value: NASDAQ
# _---------------------_
# Value: Quote-0007
# Datatype: None
# Python value: Quote-0007
# _---------------------_
# Value: 100
# Datatype: None
# Python value: 100
# _---------------------_
# Value: Quote-0045
# Datatype: None
# Python value: Quote-0045
# _---------------------_
# Value: 10
# Datatype: None
# Python value: 10
# _---------------------_
# Value: 10
# Datatype: None
# Python value: 10
# _---------------------_
# Value: BSE
# Datatype: None
# Python value: BSE
# _---------------------_
# Value: BSE
# Datatype: None
# Python value: BSE
# _---------------------_
# Value: ASX
# Datatype: None
# Python value: ASX
# _---------------------_
# Value: Quote-0028
# Datatype: None
# Python value: Quote-0028
# _---------------------_
# Value: 10
# Datatype: None
# Python value: 10
# _---------------------_
# Value: 1000
# Datatype: None
# Python value: 1000
# _---------------------_
# Value: Quote-0033
# Datatype: None
# Python value: Quote-0033
# _---------------------_
# Value: TSE
# Datatype: None
# Python value: TSE
# _---------------------_
# Value: 100
# Datatype: None
# Python value: 100
# _---------------------_
# Value: 1
# Datatype: None
# Python value: 1
# _---------------------_
# Value: SSE
# Datatype: None
# Python value: SSE
# _---------------------_
# Value: Euronext
# Datatype: None
# Python value: Euronext
# _---------------------_
# Value: Quote-0031
# Datatype: None
# Python value: Quote-0031
# _---------------------_
# Value: Quote-0056
# Datatype: None
# Python value: Quote-0056
# _---------------------_
# Value: HKEX
# Datatype: None
# Python value: HKEX
# _---------------------_
# Value: HKEX
# Datatype: None
# Python value: HKEX
# _---------------------_
# Value: Quote-0004
# Datatype: None
# Python value: Quote-0004
# _---------------------_
# Value: LSE
# Datatype: None
# Python value: LSE
# _---------------------_
# Value: Quote-0001
# Datatype: None
# Python value: Quote-0001
# _---------------------_
# Value: 1000
# Datatype: None
# Python value: 1000
# _---------------------_
# Value: 100
# Datatype: None
# Python value: 100
# _---------------------_
# Value: SGX
# Datatype: None
# Python value: SGX
# _---------------------_
# Value: Quote-0010
# Datatype: None
# Python value: Quote-0010
# _---------------------_
# Value: SSE
# Datatype: None
# Python value: SSE
# _---------------------_
# Value: 1
# Datatype: None
# Python value: 1
# _---------------------_
# Value: Quote-0009
# Datatype: None
# Python value: Quote-0009
# _---------------------_
# Value: 100
# Datatype: None
# Python value: 100
# _---------------------_
# Value: NYSE
# Datatype: None
# Python value: NYSE
# _---------------------_
# Value: Quote-0036
# Datatype: None
# Python value: Quote-0036
# _---------------------_
# Value: 100
# Datatype: None
# Python value: 100
# _---------------------_
# Value: TSE
# Datatype: None
# Python value: TSE
# _---------------------_
# Value: 1
# Datatype: None
# Python value: 1
# _---------------------_
# Value: Quote-0027
# Datatype: None
# Python value: Quote-0027
# _---------------------_
# Value: 1
# Datatype: None
# Python value: 1
# _---------------------_
# Value: NASDAQ
# Datatype: None
# Python value: NASDAQ
# _---------------------_
# Value: Quote-0048
# Datatype: None
# Python value: Quote-0048
# _---------------------_
# Value: SGX
# Datatype: None
# Python value: SGX
# _---------------------_
# Value: LSE
# Datatype: None
# Python value: LSE
# _---------------------_
# Value: 10
# Datatype: None
# Python value: 10
# _---------------------_
# Value: Quote-0003
# Datatype: None
# Python value: Quote-0003
# _---------------------_
# Value: Quote-0020
# Datatype: None
# Python value: Quote-0020
# _---------------------_
# Value: NYSE
# Datatype: None
# Python value: NYSE
# _---------------------_
# Value: SGX
# Datatype: None
# Python value: SGX
# _---------------------_
# Value: Quote-0005
# Datatype: None
# Python value: Quote-0005
# _---------------------_
# Value: Quote-0058
# Datatype: None
# Python value: Quote-0058
# _---------------------_
# Value: ASX
# Datatype: None
# Python value: ASX
# _---------------------_
# Value: 10
# Datatype: None
# Python value: 10
# _---------------------_
# Value: Quote-0018
# Datatype: None
# Python value: Quote-0018
# _---------------------_
# Value: 100
# Datatype: None
# Python value: 100
# _---------------------_
# Value: 100
# Datatype: None
# Python value: 100
# _---------------------_
# Value: 1
# Datatype: None
# Python value: 1
# _---------------------_
# Value: NASDAQ
# Datatype: None
# Python value: NASDAQ
# _---------------------_
# Value: Quote-0052
# Datatype: None
# Python value: Quote-0052
# _---------------------_
# Value: Quote-0008
# Datatype: None
# Python value: Quote-0008
# _---------------------_
# Value: ASX
# Datatype: None
# Python value: ASX
# _---------------------_
# Value: Quote-0037
# Datatype: None
# Python value: Quote-0037
# _---------------------_
# Value: 100
# Datatype: None
# Python value: 100
# _---------------------_
# Value: Quote-0038
# Datatype: None
# Python value: Quote-0038
# _---------------------_
# Value: Quote-0015
# Datatype: None
# Python value: Quote-0015
# _---------------------_
# Value: BSE
# Datatype: None
# Python value: BSE
# _---------------------_
# Value: 100
# Datatype: None
# Python value: 100
# _---------------------_
# Value: 1000
# Datatype: None
# Python value: 1000
# _---------------------_
# Value: 10
# Datatype: None
# Python value: 10
# _---------------------_
# Value: BSE
# Datatype: None
# Python value: BSE
# _---------------------_
# Value: Quote-0014
# Datatype: None
# Python value: Quote-0014
# _---------------------_
# Value: Euronext
# Datatype: None
# Python value: Euronext
# _---------------------_
# Value: Quote-0043
# Datatype: None
# Python value: Quote-0043
# _---------------------_
# Value: Quote-0044
# Datatype: None
# Python value: Quote-0044
# _---------------------_
# Value: SGX
# Datatype: None
# Python value: SGX
# _---------------------_
# Value: LSE
# Datatype: None
# Python value: LSE
# _---------------------_
# Value: 1000
# Datatype: None
# Python value: 1000
# _---------------------_

# %% [markdown]
# # =========================
#
# # 10. Graph Navigation
#
# # =========================

# %%
# Pick one subject
sample_subject = next(iter(subjects))

print("\nAll triples for one subject:")
for p, o in g.predicate_objects(subject=sample_subject):
    print(p, o)
# Out:
# All triples for one subject:
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://permid.org/ontology/financial/Delisted
# http://www.w3.org/2000/01/rdf-schema#label Quote-0033
# https://permid.org/ontology/financial/listedOn LSE
# https://permid.org/ontology/financial/quoteCurrency https://permid.org/1-DKK
# https://permid.org/ontology/financial/quotedOrganization https://permid.org/org-0003
# https://permid.org/ontology/financial/lotSize 10

# %% [markdown]
# # =========================
#
# # 11. Build NetworkX Graph
#
# # =========================

# %%
G_nx = nx.DiGraph()

for s, p, o in g:
    if isinstance(o, URIRef):
        G_nx.add_edge(str(s), str(o), label=str(p))

print("NetworkX nodes:", G_nx.number_of_nodes())
print("NetworkX edges:", G_nx.number_of_edges())

# Visualize small subgraph
sub_nodes = list(G_nx.nodes())[:50]
subgraph = G_nx.subgraph(sub_nodes)

plt.figure()
pos = nx.spring_layout(subgraph)
nx.draw(subgraph, pos, node_size=50, with_labels=False)
plt.show()
# Out:
# NetworkX nodes: 113
# NetworkX edges: 180

# %% [markdown]
# # =========================
#
# # 12. Serialization
#
# # =========================

# %%
# Save graph in different formats
g.serialize("output.ttl", format="turtle")
g.serialize("output.rdf", format="xml")
# Out:
# <Graph identifier=N7527cd03646d404093c4d50f9225fd38 (<class 'rdflib.graph.Graph'>)>

# %% [markdown]
# # =========================
#
# # 13. Advanced: Reasoning (basic)
#
# # =========================

# %%
# Example: find all broader chains manually


def get_broader_chain(graph, node, depth=3):
    chain = []
    current = node
    for _ in range(depth):
        parent = list(graph.objects(current, SKOS.broader))
        if not parent:
            break
        current = parent[0]
        chain.append(current)
    return chain


sample = next(iter(subjects))
print("\nBroader chain:", get_broader_chain(g, sample))
# Out:
# Broader chain: []

# %% [markdown]
# # =========================
#
# # 14. Statistics & Insights
#
# # =========================

# %%
print("\nTop predicates:")
print(predicate_counts.head(30))

# Distribution plot
plt.figure()
predicate_counts.plot(kind="bar")
plt.show()
# Out:
# Top predicates:
# predicate
# https://permid.org/ontology/financial/lotSize               60
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type             60
# http://www.w3.org/2000/01/rdf-schema#label                  60
# https://permid.org/ontology/financial/quotedOrganization    60
# https://permid.org/ontology/financial/listedOn              60
# https://permid.org/ontology/financial/quoteCurrency         60
# Name: count, dtype: int64

# %% [markdown]
# # =========================
#
# # END
#
# # =========================
