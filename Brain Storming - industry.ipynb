# %% [markdown]
# # RDF N-Triples Analysis Notebook using rdflib

# %%
name = "industry"

# %% [markdown]
# # =========================
#
# # 1. Setup
#
# # =========================

# %%
from rdflib import Graph, URIRef, Literal, Namespace
from rdflib.namespace import RDF, RDFS, SKOS, XSD
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

# %% [markdown]
# ## Helper Functions

# %%
def parse_file_safe(graph, path):
    encodings = ["utf-8", "latin-1", "cp1252"]

    for enc in encodings:
        try:
            with open(path, "r", encoding=enc) as f:
                graph.parse(f, format="nt")
            print(f"Loaded {path} with {enc}")
            return
        except UnicodeDecodeError:
            continue

    print(f"Failed to parse {path}")

# %% [markdown]
# # =========================
#
# # 2. Load N-Triples Files
#
# # =========================

# %%
import os

data_dir = "data"
g = Graph()


for file in os.listdir(data_dir):
    if name in file and file.endswith(".ntriples"):
        path = os.path.join(data_dir, file)
        print(f"Loading {path}")
        parse_file_safe(g, path)

print(f"Total triples loaded: {len(g)}")
# Out:
# Loading data\OpenPermID-bulk-industry.ntriples
# Loaded data\OpenPermID-bulk-industry.ntriples with utf-8
# Total triples loaded: 202

# %% [markdown]
# # =========================
#
# # 3. Inspect Basic Structure
#
# # =========================

# %%
# Print first 10 triples
for i, (s, p, o) in enumerate(g):
    if i >= 10:
        break
    print(s, p, o)
# Out:
# https://permid.org/ind-Metals http://www.w3.org/2000/01/rdf-schema#label Metals
# https://permid.org/sector-Materials https://permid.org/ontology/financial/hasIndustry https://permid.org/ind-Packaging
# https://permid.org/sector-ConsumerDiscretionary https://permid.org/ontology/financial/hasIndustry https://permid.org/ind-Hotels
# https://permid.org/sector-CommunicationServices http://www.w3.org/2000/01/rdf-schema#label CommunicationServices
# https://permid.org/ind-Telecom http://www.w3.org/2000/01/rdf-schema#label Telecom
# https://permid.org/ind-HouseholdProducts http://www.w3.org/2000/01/rdf-schema#label HouseholdProducts
# https://permid.org/sector-Utilities http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://permid.org/ontology/financial/BusinessSector
# https://permid.org/sector-Industrials http://www.w3.org/2000/01/rdf-schema#label Industrials
# https://permid.org/ind-MediaEntertainment http://www.w3.org/2000/01/rdf-schema#label MediaEntertainment
# https://permid.org/sector-Energy http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://permid.org/ontology/financial/BusinessSector

# %% [markdown]
# # =========================
#
# # 4. Explore Unique Elements
#
# # =========================

# %%
subjects = set()
predicates = set()
uri_predicates = set()
literal_predicates = set()
objects = set()
both = set()
count = 0
for s, p, o in g:
    subjects.add(s)
    predicates.add(p)
    objects.add(o)
    both.add(s)
    both.add(o)
    if isinstance(o, Literal):
        literal_predicates.add(p)
    else:
        uri_predicates.add(p)
    count += 1


print("Total Size:", count)
print("Unique subjects:", len(subjects))
print("Unique predicates:", len(predicates))
print("Unique objects:", len(objects))
print("Unique Both:", len(both))
# Out:
# Total Size: 202
# Unique subjects: 56
# Unique predicates: 4
# Unique objects: 114
# Unique Both: 114

# %%
print(uri_predicates)
# Out:
# {rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('https://permid.org/ontology/financial/hasIndustry'), rdflib.term.URIRef('https://permid.org/ontology/financial/isPartOf')}

# %%
print(literal_predicates)
# Out:
# {rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label')}

# %% [markdown]
# Conclusion: Majority of subjects are not objects

# %% [markdown]
# # =========================
#
# # 5. Convert to DataFrame
#
# # =========================

# %%
data = [(str(s), str(p), str(o)) for s, p, o in g]
df = pd.DataFrame(data, columns=["subject", "predicate", "object"])

df.head()

# Predicate frequency
predicate_counts = df["predicate"].value_counts()
predicate_counts.head(10)
# Out:
# predicate
# http://www.w3.org/2000/01/rdf-schema#label           56
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type      56
# https://permid.org/ontology/financial/hasIndustry    45
# https://permid.org/ontology/financial/isPartOf       45
# Name: count, dtype: int64

# %% [markdown]
# # =========================
#
# # 6. Namespace Handling
#
# # =========================

# %%
EX = Namespace("http://permid.org/")

# Bind namespace (useful for serialization)
g.bind("ex", EX)

# %% [markdown]
# # =========================
#
# # 7. Filtering Triples
#
# # =========================

# %%
# Example: get all labels
labels = []
for s, p, o in g.triples((None, RDFS.label, None)):
    labels.append((s, o))

print("Sample labels:")
print(labels[:10])
# Out:
# Sample labels:
# [(rdflib.term.URIRef('https://permid.org/sector-Technology'), rdflib.term.Literal('Technology', lang='en')), (rdflib.term.URIRef('https://permid.org/ind-Software'), rdflib.term.Literal('Software', lang='en')), (rdflib.term.URIRef('https://permid.org/ind-Hardware'), rdflib.term.Literal('Hardware', lang='en')), (rdflib.term.URIRef('https://permid.org/ind-Semiconductors'), rdflib.term.Literal('Semiconductors', lang='en')), (rdflib.term.URIRef('https://permid.org/ind-ITServices'), rdflib.term.Literal('ITServices', lang='en')), (rdflib.term.URIRef('https://permid.org/ind-InternetRetail'), rdflib.term.Literal('InternetRetail', lang='en')), (rdflib.term.URIRef('https://permid.org/sector-Financials'), rdflib.term.Literal('Financials', lang='en')), (rdflib.term.URIRef('https://permid.org/ind-Banking'), rdflib.term.Literal('Banking', lang='en')), (rdflib.term.URIRef('https://permid.org/ind-Insurance'), rdflib.term.Literal('Insurance', lang='en')), (rdflib.term.URIRef('https://permid.org/ind-AssetManagement'), rdflib.term.Literal('AssetManagement', lang='en'))]

# %% [markdown]
# # =========================
#
# # 8. SPARQL Queries
#
# # =========================

# %%
query = """
SELECT ?s ?label
WHERE {
    # ?s <http://www.w3.org/2000/01/rdf-schema#label> ?label .
}
LIMIT 10
"""

for row in g.query(query):
    print(row)

# More complex query: hierarchical relations
query_hierarchy = """
SELECT ?child ?parent
WHERE {
    # ?child <http://www.w3.org/2004/02/skos/core#broader> ?parent .
}
LIMIT 10
"""

for row in g.query(query_hierarchy):
    print(row)
# Out:
# (rdflib.term.URIRef('https://permid.org/sector-Technology'), rdflib.term.Literal('Technology', lang='en'))
# (rdflib.term.URIRef('https://permid.org/ind-Software'), rdflib.term.Literal('Software', lang='en'))
# (rdflib.term.URIRef('https://permid.org/ind-Hardware'), rdflib.term.Literal('Hardware', lang='en'))
# (rdflib.term.URIRef('https://permid.org/ind-Semiconductors'), rdflib.term.Literal('Semiconductors', lang='en'))
# (rdflib.term.URIRef('https://permid.org/ind-ITServices'), rdflib.term.Literal('ITServices', lang='en'))
# (rdflib.term.URIRef('https://permid.org/ind-InternetRetail'), rdflib.term.Literal('InternetRetail', lang='en'))
# (rdflib.term.URIRef('https://permid.org/sector-Financials'), rdflib.term.Literal('Financials', lang='en'))
# (rdflib.term.URIRef('https://permid.org/ind-Banking'), rdflib.term.Literal('Banking', lang='en'))
# (rdflib.term.URIRef('https://permid.org/ind-Insurance'), rdflib.term.Literal('Insurance', lang='en'))
# (rdflib.term.URIRef('https://permid.org/ind-AssetManagement'), rdflib.term.Literal('AssetManagement', lang='en'))

# %% [markdown]
# # =========================
#
# # 9. Working with Literals
#
# # =========================

# %%
for s, p, o in g:
    if isinstance(o, Literal):
        print("Value:", o)
        print("Datatype:", o.datatype)
        print("Python value:", o.toPython())
        print("_---------------------_")
# Out:
# Value: Metals
# Datatype: None
# Python value: Metals
# _---------------------_
# Value: CommunicationServices
# Datatype: None
# Python value: CommunicationServices
# _---------------------_
# Value: Telecom
# Datatype: None
# Python value: Telecom
# _---------------------_
# Value: HouseholdProducts
# Datatype: None
# Python value: HouseholdProducts
# _---------------------_
# Value: Industrials
# Datatype: None
# Python value: Industrials
# _---------------------_
# Value: MediaEntertainment
# Datatype: None
# Python value: MediaEntertainment
# _---------------------_
# Value: Chemicals
# Datatype: None
# Python value: Chemicals
# _---------------------_
# Value: Biotechnology
# Datatype: None
# Python value: Biotechnology
# _---------------------_
# Value: Healthcare
# Datatype: None
# Python value: Healthcare
# _---------------------_
# Value: Software
# Datatype: None
# Python value: Software
# _---------------------_
# Value: CommercialREIT
# Datatype: None
# Python value: CommercialREIT
# _---------------------_
# Value: MultiUtilities
# Datatype: None
# Python value: MultiUtilities
# _---------------------_
# Value: Aerospace
# Datatype: None
# Python value: Aerospace
# _---------------------_
# Value: RenewableEnergy
# Datatype: None
# Python value: RenewableEnergy
# _---------------------_
# Value: Technology
# Datatype: None
# Python value: Technology
# _---------------------_
# Value: IntegratedOilGas
# Datatype: None
# Python value: IntegratedOilGas
# _---------------------_
# Value: ElectricUtilities
# Datatype: None
# Python value: ElectricUtilities
# _---------------------_
# Value: Transportation
# Datatype: None
# Python value: Transportation
# _---------------------_
# Value: Packaging
# Datatype: None
# Python value: Packaging
# _---------------------_
# Value: Materials
# Datatype: None
# Python value: Materials
# _---------------------_
# Value: EnergyEquipment
# Datatype: None
# Python value: EnergyEquipment
# _---------------------_
# Value: REITFinance
# Datatype: None
# Python value: REITFinance
# _---------------------_
# Value: DiversifiedREIT
# Datatype: None
# Python value: DiversifiedREIT
# _---------------------_
# Value: WaterUtilities
# Datatype: None
# Python value: WaterUtilities
# _---------------------_
# Value: RealEstate
# Datatype: None
# Python value: RealEstate
# _---------------------_
# Value: Automotive
# Datatype: None
# Python value: Automotive
# _---------------------_
# Value: ITServices
# Datatype: None
# Python value: ITServices
# _---------------------_
# Value: Semiconductors
# Datatype: None
# Python value: Semiconductors
# _---------------------_
# Value: Hardware
# Datatype: None
# Python value: Hardware
# _---------------------_
# Value: MedicalDevices
# Datatype: None
# Python value: MedicalDevices
# _---------------------_
# Value: Tobacco
# Datatype: None
# Python value: Tobacco
# _---------------------_
# Value: GasUtilities
# Datatype: None
# Python value: GasUtilities
# _---------------------_
# Value: Hotels
# Datatype: None
# Python value: Hotels
# _---------------------_
# Value: ResidentialREIT
# Datatype: None
# Python value: ResidentialREIT
# _---------------------_
# Value: ConsumerStaples
# Datatype: None
# Python value: ConsumerStaples
# _---------------------_
# Value: AssetManagement
# Datatype: None
# Python value: AssetManagement
# _---------------------_
# Value: RetailApparel
# Datatype: None
# Python value: RetailApparel
# _---------------------_
# Value: PersonalProducts
# Datatype: None
# Python value: PersonalProducts
# _---------------------_
# Value: Pharmaceuticals
# Datatype: None
# Python value: Pharmaceuticals
# _---------------------_
# Value: MediaBroadcast
# Datatype: None
# Python value: MediaBroadcast
# _---------------------_
# Value: InteractiveMedia
# Datatype: None
# Python value: InteractiveMedia
# _---------------------_
# Value: InternetRetail
# Datatype: None
# Python value: InternetRetail
# _---------------------_
# Value: Mining
# Datatype: None
# Python value: Mining
# _---------------------_
# Value: DefenseContractors
# Datatype: None
# Python value: DefenseContractors
# _---------------------_
# Value: HealthcareServices
# Datatype: None
# Python value: HealthcareServices
# _---------------------_
# Value: Utilities
# Datatype: None
# Python value: Utilities
# _---------------------_
# Value: Insurance
# Datatype: None
# Python value: Insurance
# _---------------------_
# Value: FoodBeverage
# Datatype: None
# Python value: FoodBeverage
# _---------------------_
# Value: Construction
# Datatype: None
# Python value: Construction
# _---------------------_
# Value: CapitalMarkets
# Datatype: None
# Python value: CapitalMarkets
# _---------------------_
# Value: Banking
# Datatype: None
# Python value: Banking
# _---------------------_
# Value: OilGasExploration
# Datatype: None
# Python value: OilGasExploration
# _---------------------_
# Value: Financials
# Datatype: None
# Python value: Financials
# _---------------------_
# Value: Machinery
# Datatype: None
# Python value: Machinery
# _---------------------_
# Value: ConsumerDiscretionary
# Datatype: None
# Python value: ConsumerDiscretionary
# _---------------------_
# Value: Energy
# Datatype: None
# Python value: Energy
# _---------------------_

# %% [markdown]
# # =========================
#
# # 10. Graph Navigation
#
# # =========================

# %%
# Pick one subject
sample_subject = next(iter(subjects))

print("\nAll triples for one subject:")
for p, o in g.predicate_objects(subject=sample_subject):
    print(p, o)
# Out:
# All triples for one subject:
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://permid.org/ontology/financial/Industry
# http://www.w3.org/2000/01/rdf-schema#label Aerospace
# https://permid.org/ontology/financial/isPartOf https://permid.org/sector-Industrials

# %% [markdown]
# # =========================
#
# # 11. Build NetworkX Graph
#
# # =========================

# %%
G_nx = nx.DiGraph()

for s, p, o in g:
    if isinstance(o, URIRef):
        G_nx.add_edge(str(s), str(o), label=str(p))

print("NetworkX nodes:", G_nx.number_of_nodes())
print("NetworkX edges:", G_nx.number_of_edges())

# Visualize small subgraph
sub_nodes = list(G_nx.nodes())[:50]
subgraph = G_nx.subgraph(sub_nodes)

plt.figure()
pos = nx.spring_layout(subgraph)
nx.draw(subgraph, pos, node_size=50, with_labels=False)
plt.show()
# Out:
# NetworkX nodes: 58
# NetworkX edges: 146

# %% [markdown]
# # =========================
#
# # 12. Serialization
#
# # =========================

# %%
# Save graph in different formats
g.serialize("output.ttl", format="turtle")
g.serialize("output.rdf", format="xml")
# Out:
# <Graph identifier=Nd7f577242f184a6c92c749e2631de054 (<class 'rdflib.graph.Graph'>)>

# %% [markdown]
# # =========================
#
# # 13. Advanced: Reasoning (basic)
#
# # =========================

# %%
# Example: find all broader chains manually


def get_broader_chain(graph, node, depth=3):
    chain = []
    current = node
    for _ in range(depth):
        parent = list(graph.objects(current, SKOS.broader))
        if not parent:
            break
        current = parent[0]
        chain.append(current)
    return chain


sample = next(iter(subjects))
print("\nBroader chain:", get_broader_chain(g, sample))
# Out:
# Broader chain: []

# %% [markdown]
# # =========================
#
# # 14. Statistics & Insights
#
# # =========================

# %%
print("\nTop predicates:")
print(predicate_counts.head(30))

# Distribution plot
plt.figure()
predicate_counts.plot(kind="bar")
plt.show()
# Out:
# Top predicates:
# predicate
# http://www.w3.org/2000/01/rdf-schema#label           56
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type      56
# https://permid.org/ontology/financial/hasIndustry    45
# https://permid.org/ontology/financial/isPartOf       45
# Name: count, dtype: int64

# %% [markdown]
# # =========================
#
# # END
#
# # =========================
