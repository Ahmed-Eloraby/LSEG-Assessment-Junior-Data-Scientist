# %% [markdown]
# # RDF N-Triples Analysis Notebook using rdflib

# %%
name = "person"

# %% [markdown]
# # =========================
#
# # 1. Setup
#
# # =========================

# %%
from rdflib import Graph, URIRef, Literal, Namespace
from rdflib.namespace import RDF, RDFS, SKOS, XSD
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

# %% [markdown]
# ## Helper Functions

# %%
def parse_file_safe(graph, path):
    encodings = ["utf-8", "latin-1", "cp1252"]

    for enc in encodings:
        try:
            with open(path, "r", encoding=enc) as f:
                graph.parse(f, format="nt")
            print(f"Loaded {path} with {enc}")
            return
        except UnicodeDecodeError:
            continue

    print(f"Failed to parse {path}")

# %% [markdown]
# # =========================
#
# # 2. Load N-Triples Files
#
# # =========================

# %%
import os

data_dir = "data"
g = Graph()


for file in os.listdir(data_dir):
    if name in file and file.endswith(".ntriples"):
        path = os.path.join(data_dir, file)
        print(f"Loading {path}")
        parse_file_safe(g, path)

print(f"Total triples loaded: {len(g)}")
# Out:
# Loading data\OpenPermID-bulk-person.ntriples
# Loaded data\OpenPermID-bulk-person.ntriples with utf-8
# Total triples loaded: 110

# %% [markdown]
# # =========================
#
# # 3. Inspect Basic Structure
#
# # =========================

# %%
# Print first 10 triples
for i, (s, p, o) in enumerate(g):
    if i >= 10:
        break
    print(s, p, o)
# Out:
# https://permid.org/person-0005 https://permid.org/ontology/financial/gender Male
# https://permid.org/person-0008 https://permid.org/ontology/financial/hasRole CEO
# https://permid.org/person-0004 https://permid.org/ontology/financial/employedBy https://permid.org/org-0004
# https://permid.org/person-0006 https://permid.org/ontology/financial/employedBy https://permid.org/org-0006
# https://permid.org/person-0013 https://permid.org/ontology/financial/hasRole CEO
# https://permid.org/person-0009 https://permid.org/ontology/financial/hasRole CEO
# https://permid.org/person-0019 http://www.w3.org/2000/01/rdf-schema#label Murray Auchincloss
# https://permid.org/person-0017 https://permid.org/ontology/financial/hasRole Chairman
# https://permid.org/person-0007 http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://permid.org/ontology/financial/Person
# https://permid.org/person-0002 http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://permid.org/ontology/financial/Person

# %% [markdown]
# # =========================
#
# # 4. Explore Unique Elements
#
# # =========================

# %%
subjects = set()
predicates = set()
uri_predicates = set()
literal_predicates = set()
objects = set()
both = set()
count = 0
for s, p, o in g:
    subjects.add(s)
    predicates.add(p)
    objects.add(o)
    both.add(s)
    both.add(o)
    if isinstance(o, Literal):
        literal_predicates.add(p)
    else:
        uri_predicates.add(p)
    count += 1


print("Total Size:", count)
print("Unique subjects:", len(subjects))
print("Unique predicates:", len(predicates))
print("Unique objects:", len(objects))
print("Unique Both:", len(both))
# Out:
# Total Size: 110
# Unique subjects: 22
# Unique predicates: 5
# Unique objects: 48
# Unique Both: 70

# %%
print(uri_predicates)
# Out:
# {rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('https://permid.org/ontology/financial/employedBy')}

# %%
print(literal_predicates)
# Out:
# {rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.URIRef('https://permid.org/ontology/financial/hasRole'), rdflib.term.URIRef('https://permid.org/ontology/financial/gender')}

# %% [markdown]
# Conclusion: Majority of subjects are not objects

# %% [markdown]
# # =========================
#
# # 5. Convert to DataFrame
#
# # =========================

# %%
data = [(str(s), str(p), str(o)) for s, p, o in g]
df = pd.DataFrame(data, columns=["subject", "predicate", "object"])

df.head()

# Predicate frequency
predicate_counts = df["predicate"].value_counts()
predicate_counts.head(10)
# Out:
# predicate
# https://permid.org/ontology/financial/gender        22
# https://permid.org/ontology/financial/hasRole       22
# https://permid.org/ontology/financial/employedBy    22
# http://www.w3.org/2000/01/rdf-schema#label          22
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type     22
# Name: count, dtype: int64

# %% [markdown]
# # =========================
#
# # 6. Namespace Handling
#
# # =========================

# %%
EX = Namespace("http://permid.org/")

# Bind namespace (useful for serialization)
g.bind("ex", EX)

# %% [markdown]
# # =========================
#
# # 7. Filtering Triples
#
# # =========================

# %%
# Example: get all labels
labels = []
for s, p, o in g.triples((None, RDFS.label, None)):
    labels.append((s, o))

print("Sample labels:")
print(labels[:10])
# Out:
# Sample labels:
# [(rdflib.term.URIRef('https://permid.org/person-0001'), rdflib.term.Literal('Tim Cook', lang='en')), (rdflib.term.URIRef('https://permid.org/person-0002'), rdflib.term.Literal('Satya Nadella', lang='en')), (rdflib.term.URIRef('https://permid.org/person-0003'), rdflib.term.Literal('Jamie Dimon', lang='en')), (rdflib.term.URIRef('https://permid.org/person-0004'), rdflib.term.Literal('David Solomon', lang='en')), (rdflib.term.URIRef('https://permid.org/person-0005'), rdflib.term.Literal('Noel Quinn', lang='en')), (rdflib.term.URIRef('https://permid.org/person-0006'), rdflib.term.Literal('Christian Sewing', lang='en')), (rdflib.term.URIRef('https://permid.org/person-0007'), rdflib.term.Literal('Koji Sato', lang='en')), (rdflib.term.URIRef('https://permid.org/person-0008'), rdflib.term.Literal('Jong-Hee Han', lang='en')), (rdflib.term.URIRef('https://permid.org/person-0009'), rdflib.term.Literal('Mark Schneider', lang='en')), (rdflib.term.URIRef('https://permid.org/person-0010'), rdflib.term.Literal('Wael Sawan', lang='en'))]

# %% [markdown]
# # =========================
#
# # 8. SPARQL Queries
#
# # =========================

# %%
query = """
SELECT ?s ?label
WHERE {
    # ?s <http://www.w3.org/2000/01/rdf-schema#label> ?label .
}
LIMIT 10
"""

for row in g.query(query):
    print(row)

# More complex query: hierarchical relations
query_hierarchy = """
SELECT ?child ?parent
WHERE {
    # ?child <http://www.w3.org/2004/02/skos/core#broader> ?parent .
}
LIMIT 10
"""

for row in g.query(query_hierarchy):
    print(row)
# Out:
# (rdflib.term.URIRef('https://permid.org/person-0001'), rdflib.term.Literal('Tim Cook', lang='en'))
# (rdflib.term.URIRef('https://permid.org/person-0002'), rdflib.term.Literal('Satya Nadella', lang='en'))
# (rdflib.term.URIRef('https://permid.org/person-0003'), rdflib.term.Literal('Jamie Dimon', lang='en'))
# (rdflib.term.URIRef('https://permid.org/person-0004'), rdflib.term.Literal('David Solomon', lang='en'))
# (rdflib.term.URIRef('https://permid.org/person-0005'), rdflib.term.Literal('Noel Quinn', lang='en'))
# (rdflib.term.URIRef('https://permid.org/person-0006'), rdflib.term.Literal('Christian Sewing', lang='en'))
# (rdflib.term.URIRef('https://permid.org/person-0007'), rdflib.term.Literal('Koji Sato', lang='en'))
# (rdflib.term.URIRef('https://permid.org/person-0008'), rdflib.term.Literal('Jong-Hee Han', lang='en'))
# (rdflib.term.URIRef('https://permid.org/person-0009'), rdflib.term.Literal('Mark Schneider', lang='en'))
# (rdflib.term.URIRef('https://permid.org/person-0010'), rdflib.term.Literal('Wael Sawan', lang='en'))

# %% [markdown]
# # =========================
#
# # 9. Working with Literals
#
# # =========================

# %%
for s, p, o in g:
    if isinstance(o, Literal):
        print("Value:", o)
        print("Datatype:", o.datatype)
        print("Python value:", o.toPython())
        print("_---------------------_")
# Out:
# Value: Male
# Datatype: None
# Python value: Male
# _---------------------_
# Value: CEO
# Datatype: None
# Python value: CEO
# _---------------------_
# Value: CEO
# Datatype: None
# Python value: CEO
# _---------------------_
# Value: CEO
# Datatype: None
# Python value: CEO
# _---------------------_
# Value: Murray Auchincloss
# Datatype: None
# Python value: Murray Auchincloss
# _---------------------_
# Value: Chairman
# Datatype: None
# Python value: Chairman
# _---------------------_
# Value: CEO
# Datatype: None
# Python value: CEO
# _---------------------_
# Value: Male
# Datatype: None
# Python value: Male
# _---------------------_
# Value: Warren Buffett
# Datatype: None
# Python value: Warren Buffett
# _---------------------_
# Value: Male
# Datatype: None
# Python value: Male
# _---------------------_
# Value: Male
# Datatype: None
# Python value: Male
# _---------------------_
# Value: CEO
# Datatype: None
# Python value: CEO
# _---------------------_
# Value: Christian Sewing
# Datatype: None
# Python value: Christian Sewing
# _---------------------_
# Value: CEO
# Datatype: None
# Python value: CEO
# _---------------------_
# Value: CEO
# Datatype: None
# Python value: CEO
# _---------------------_
# Value: CEO
# Datatype: None
# Python value: CEO
# _---------------------_
# Value: Male
# Datatype: None
# Python value: Male
# _---------------------_
# Value: Noel Quinn
# Datatype: None
# Python value: Noel Quinn
# _---------------------_
# Value: CEO
# Datatype: None
# Python value: CEO
# _---------------------_
# Value: Mark Zuckerberg
# Datatype: None
# Python value: Mark Zuckerberg
# _---------------------_
# Value: Jong-Hee Han
# Datatype: None
# Python value: Jong-Hee Han
# _---------------------_
# Value: Pony Ma
# Datatype: None
# Python value: Pony Ma
# _---------------------_
# Value: CEO
# Datatype: None
# Python value: CEO
# _---------------------_
# Value: Andy Jassy
# Datatype: None
# Python value: Andy Jassy
# _---------------------_
# Value: Male
# Datatype: None
# Python value: Male
# _---------------------_
# Value: CEO
# Datatype: None
# Python value: CEO
# _---------------------_
# Value: CEO
# Datatype: None
# Python value: CEO
# _---------------------_
# Value: CEO
# Datatype: None
# Python value: CEO
# _---------------------_
# Value: Male
# Datatype: None
# Python value: Male
# _---------------------_
# Value: Chairman
# Datatype: None
# Python value: Chairman
# _---------------------_
# Value: Male
# Datatype: None
# Python value: Male
# _---------------------_
# Value: Satya Nadella
# Datatype: None
# Python value: Satya Nadella
# _---------------------_
# Value: Male
# Datatype: None
# Python value: Male
# _---------------------_
# Value: Male
# Datatype: None
# Python value: Male
# _---------------------_
# Value: CEO
# Datatype: None
# Python value: CEO
# _---------------------_
# Value: CEO
# Datatype: None
# Python value: CEO
# _---------------------_
# Value: Larry Fink
# Datatype: None
# Python value: Larry Fink
# _---------------------_
# Value: Male
# Datatype: None
# Python value: Male
# _---------------------_
# Value: Koji Sato
# Datatype: None
# Python value: Koji Sato
# _---------------------_
# Value: Male
# Datatype: None
# Python value: Male
# _---------------------_
# Value: CEO
# Datatype: None
# Python value: CEO
# _---------------------_
# Value: Eddie Wu
# Datatype: None
# Python value: Eddie Wu
# _---------------------_
# Value: Male
# Datatype: None
# Python value: Male
# _---------------------_
# Value: Male
# Datatype: None
# Python value: Male
# _---------------------_
# Value: CEO
# Datatype: None
# Python value: CEO
# _---------------------_
# Value: Male
# Datatype: None
# Python value: Male
# _---------------------_
# Value: Tim Cook
# Datatype: None
# Python value: Tim Cook
# _---------------------_
# Value: Elon Musk
# Datatype: None
# Python value: Elon Musk
# _---------------------_
# Value: Bernard Arnault
# Datatype: None
# Python value: Bernard Arnault
# _---------------------_
# Value: Wael Sawan
# Datatype: None
# Python value: Wael Sawan
# _---------------------_
# Value: CEO
# Datatype: None
# Python value: CEO
# _---------------------_
# Value: Thomas Schinecker
# Datatype: None
# Python value: Thomas Schinecker
# _---------------------_
# Value: Sundar Pichai
# Datatype: None
# Python value: Sundar Pichai
# _---------------------_
# Value: David Solomon
# Datatype: None
# Python value: David Solomon
# _---------------------_
# Value: Male
# Datatype: None
# Python value: Male
# _---------------------_
# Value: Roland Busch
# Datatype: None
# Python value: Roland Busch
# _---------------------_
# Value: Male
# Datatype: None
# Python value: Male
# _---------------------_
# Value: Male
# Datatype: None
# Python value: Male
# _---------------------_
# Value: Jamie Dimon
# Datatype: None
# Python value: Jamie Dimon
# _---------------------_
# Value: Male
# Datatype: None
# Python value: Male
# _---------------------_
# Value: Male
# Datatype: None
# Python value: Male
# _---------------------_
# Value: Male
# Datatype: None
# Python value: Male
# _---------------------_
# Value: Mark Schneider
# Datatype: None
# Python value: Mark Schneider
# _---------------------_
# Value: CEO
# Datatype: None
# Python value: CEO
# _---------------------_
# Value: Male
# Datatype: None
# Python value: Male
# _---------------------_
# Value: Chairman
# Datatype: None
# Python value: Chairman
# _---------------------_

# %% [markdown]
# # =========================
#
# # 10. Graph Navigation
#
# # =========================

# %%
# Pick one subject
sample_subject = next(iter(subjects))

print("\nAll triples for one subject:")
for p, o in g.predicate_objects(subject=sample_subject):
    print(p, o)
# Out:
# All triples for one subject:
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://permid.org/ontology/financial/Person
# http://www.w3.org/2000/01/rdf-schema#label Elon Musk
# https://permid.org/ontology/financial/hasRole CEO
# https://permid.org/ontology/financial/employedBy https://permid.org/org-0018
# https://permid.org/ontology/financial/gender Male

# %% [markdown]
# # =========================
#
# # 11. Build NetworkX Graph
#
# # =========================

# %%
G_nx = nx.DiGraph()

for s, p, o in g:
    if isinstance(o, URIRef):
        G_nx.add_edge(str(s), str(o), label=str(p))

print("NetworkX nodes:", G_nx.number_of_nodes())
print("NetworkX edges:", G_nx.number_of_edges())

# Visualize small subgraph
sub_nodes = list(G_nx.nodes())[:50]
subgraph = G_nx.subgraph(sub_nodes)

plt.figure()
pos = nx.spring_layout(subgraph)
nx.draw(subgraph, pos, node_size=50, with_labels=False)
plt.show()
# Out:
# NetworkX nodes: 45
# NetworkX edges: 44

# %% [markdown]
# # =========================
#
# # 12. Serialization
#
# # =========================

# %%
# Save graph in different formats
g.serialize("output.ttl", format="turtle")
g.serialize("output.rdf", format="xml")
# Out:
# <Graph identifier=N1ff86b7c679d449db7e529b9a61dbd81 (<class 'rdflib.graph.Graph'>)>

# %% [markdown]
# # =========================
#
# # 13. Advanced: Reasoning (basic)
#
# # =========================

# %%
# Example: find all broader chains manually


def get_broader_chain(graph, node, depth=3):
    chain = []
    current = node
    for _ in range(depth):
        parent = list(graph.objects(current, SKOS.broader))
        if not parent:
            break
        current = parent[0]
        chain.append(current)
    return chain


sample = next(iter(subjects))
print("\nBroader chain:", get_broader_chain(g, sample))
# Out:
# Broader chain: []

# %% [markdown]
# # =========================
#
# # 14. Statistics & Insights
#
# # =========================

# %%
print("\nTop predicates:")
print(predicate_counts.head(30))

# Distribution plot
plt.figure()
predicate_counts.plot(kind="bar")
plt.show()
# Out:
# Top predicates:
# predicate
# https://permid.org/ontology/financial/gender        22
# https://permid.org/ontology/financial/hasRole       22
# https://permid.org/ontology/financial/employedBy    22
# http://www.w3.org/2000/01/rdf-schema#label          22
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type     22
# Name: count, dtype: int64

# %% [markdown]
# # =========================
#
# # END
#
# # =========================
